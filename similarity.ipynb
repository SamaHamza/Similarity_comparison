# %% [markdown]
# #Import the needed libraries:
#
# ---

# %%
# First of all we need to download the needed libraries:
# !pip install transformers

# %%
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import pandas as pd
import numpy as np
import string
import math
import re
import torch

# %% [markdown]
# ###Data reading :

# %%
data=pd.read_csv('/content/Arabic_dataset.csv')

# %%
# taking a copy from the main dataset:
df = data.copy(deep=True)

# %%
#shape of the data :
df.shape
# Out:
# (5314, 2)

# %%
#displaying the dataset:
df.head()
# Out:
#                                                Title  \
# 0  كيف تعمل نماذج الذكاء الاصطناعي مثل ChatGPT؟ -...
# 1  الذكاء الاصطناعي قد يحرمنا من أهم ميزة في الإن...
# 2  رئيس مايكروسوفت: "التزييف العميق" أكبر المخاوف...
# 3  استخبارات غربية: قراصنة صينيون يتجسسون على منش...
# 4  مستخدما تقنية الذكاء الاصطناعي.. محتال في الصي...
#
#                                              Article
# 0  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...
# 1  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...
# 2  قال رئيس مايكروسوفت (Microsoft) براد سميث، الخ...
# 3  قالت وكالات استخبار غربية وشركة مايكروسوفت إن ...
# 4  استخدم محتال في الصين تقنية الذكاء الاصطناعي ل...

# %%
# Dropping the unwanted columns:
df.drop(columns ="Title", inplace = True)

# %%
df.head()
# Out:
#                                              Article
# 0  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...
# 1  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...
# 2  قال رئيس مايكروسوفت (Microsoft) براد سميث، الخ...
# 3  قالت وكالات استخبار غربية وشركة مايكروسوفت إن ...
# 4  استخدم محتال في الصين تقنية الذكاء الاصطناعي ل...

# %%
#detecting & removing the duplicates articles :
print('# Duplicate : ',df.duplicated().sum())
df.drop_duplicates(inplace=True)

#checking if there is nan values :
print('# NANS:',df.isna().sum())
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)
# Out:
# # Duplicate :  382
# # NANS: Article    0
# dtype: int64

# %%
#shape of the data after removing the duplicates:
df.shape
# Out:
# (4932, 1)

# %%
# Counting the words in each article:
df["word_count"] = df["Article"].apply(lambda x: len(x.split(" ")))
print(df["word_count"].describe())

# %%
df["char_count"] = df["Article"].apply(len)
print(df["char_count"] .describe())
# Out:
# count     4932.000000
# mean      3156.041768
# std       2949.771498
# min         70.000000
# 25%       1601.000000
# 50%       2364.000000
# 75%       3650.250000
# max      59946.000000
# Name: char_count, dtype: float64

# %%
df.head(10)
# Out:
#                                              Article  word_count  char_count
# 0  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...        1123        6503
# 1  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...        1331        7460
# 2  قال رئيس مايكروسوفت (Microsoft) براد سميث، الخ...         292        1773
# 3  قالت وكالات استخبار غربية وشركة مايكروسوفت إن ...         580        3669
# 4  استخدم محتال في الصين تقنية الذكاء الاصطناعي ل...         215        1179
# 5  شهد العقدان الأخيران من القرن العشرين والأول م...         806        4992
# 6  أشارت الرابطة الألمانية للبنوك إلى ضرورة توخي ...         282        1680
# 7  تعتبر ميزة "التراجع" (Undo) من الوظائف المهمة ...         203        1098
# 8  فرضت الهيئة المعنية بتنظيم خصوصية البيانات بال...         217        1340
# 9  أعلنت شركة آبل إطلاق الإصدارات الجديدة من برنا...         300        1829

# %%
df.drop(columns =['char_count', 'word_count'], axis = 1)
# Out:
#                                                 Article
# 0     البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...
# 1     البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...
# 2     قال رئيس مايكروسوفت (Microsoft) براد سميث، الخ...
# 3     قالت وكالات استخبار غربية وشركة مايكروسوفت إن ...
# 4     استخدم محتال في الصين تقنية الذكاء الاصطناعي ل...
# ...                                                 ...
# 4927  تمت الكتابة بواسطة: رهف الفلاحات آخر تحديث: ١٣...
# 4928  تمت الكتابة بواسطة: أسماء عبدالعزيز آخر تحديث:...
# 4929  تمت الكتابة بواسطة: تسنيم شلبي آخر تحديث: ٠٤:٤...
# 4930  تمت الكتابة بواسطة: رشا الصوالحة تم التدقيق بو...
# 4931  تمت الكتابة بواسطة: أماني المشاقبة تم التدقيق ...
#
# [4932 rows x 1 columns]

# %% [markdown]
# ## Starting the Pre-Processing Stage \:
#
# ---

# %%
# Customized Stop words list :
stop_words =[ "تصفحك", "خدماتنا ", "لموقعنا","كوكيز ","وعلى ","سياسة ","الخصوصية","بواسطه","بواسطة", "الكتابه","الكتابة", "تمت","تحديث",'آخر','جميع' ,'الحقوق',' محفوظة ','©','موضوع',' على','تابع', 'الجزيرة','نت','ولكن', 'هلا', 'لو', 'هذي', 'أكثر', 'لم', 'تين', 'إليك', 'ليستا', 'آه', 'وهو', 'قد', 'فإن', 'لعل', 'مذ', 'اللواتي', 'وإن', 'غير', 'هذه', 'إما', 'أقل', 'ليسوا', 'لستما', 'شتان', 'كليهما', 'التي', 'اللتان', 'هما', 'ليست', 'ممن', 'هاك', 'إي', 'لئن', 'ثم', 'عليه', 'تي', 'ته', 'ذواتا', 'أف', 'تلكما', 'مهما', 'سوف', 'هنا', 'أنتم', 'إنه', 'بهما', 'بهن', 'لهن', 'ليت', 'بعض', 'بعد', 'ذه', 'بلى', 'أيها', 'تلكم', 'عدا', 'منها', 'بكم', 'نحن', 'بس', 'كليكما', 'هيا', 'حاشا', 'هيت', 'إذا', 'اللائي', 'ذا', 'ذواتي', 'بنا', 'فمن', 'لي', 'ليس', 'والذي', 'ذلكن', 'لسنا', 'اللاتي', 'أولئك', 'بي', 'اللتين', 'ذات', 'ريث', 'لن', 'فيها', 'لكن', 'لولا', 'لوما', 'ألا', 'كأي', 'هذا', 'كلتا', 'نعم', 'كي', 'إيه', 'حين', 'كما', 'فإذا', 'ذوا', 'هم', 'بها', 'مه', 'هذان', 'ما', 'ليسا', 'آها', 'ها', 'هاتين', 'بل', 'تلك', 'هاتي', 'ذلك', 'كأن', 'إليكم', 'أنت', 'كذا', 'ذلكم', 'حيثما', 'أنى', 'فلا', 'عن', 'لسن', 'لكنما', 'كل', 'عند', 'سوى', 'في', 'كلا', 'إذ', 'حتى', 'كذلك', 'هي', 'بين', 'إن', 'دون', 'بمن', 'الذين', 'عليك', 'ماذا', 'هاته', 'هناك', 'هنالك', 'وإذا', 'له', 'لا', 'ولا', 'بكما', 'كلما', 'وما', 'ذو', 'فيه', 'كيت', 'اللذان', 'لكي', 'أولاء', 'تينك', 'ثمة', 'مما', 'ذلكما', 'ذين', 'ولو', 'منذ', 'بك', 'كيفما', 'بما', 'لست', 'والذين', 'حيث', 'ذانك', 'عسى', 'إنما', 'لكم', 'أين', 'يا', 'أم', 'لهم', 'بخ', 'فيما', 'اللذين', 'لستم', 'ومن', 'من', 'هن', 'هكذا', 'أي', 'لكما', 'هاتان', 'كأنما', 'أن', 'ذاك', 'عما', 'هو', 'لهما', 'الذي', 'أنتن', 'إذما', 'ذينك', 'هؤلاء', 'أما', 'ذي', 'على', 'هاهنا', 'إذن', 'إليكما', 'حبذا', 'هيهات', 'به', 'مع', 'وإذ', 'لك', 'نحو', 'لاسيما', 'أو', 'أنا', 'آي', 'إليكن', 'لنا', 'أوه', 'أينما', 'خلا', 'فيم', 'إنا', 'هل', 'كيف', 'بكن', 'إلى', 'ذان', 'أنتما', 'عل', 'كم', 'لستن', 'لما', 'بهم', 'منه', 'بيد', 'لكيلا', 'كلاهما', 'متى', 'بماذا', 'إلا', 'هذين', 'لدى', 'لها', 'اللتيا', 'كأين']

# %%
# Detection and Cleansing from the text :
def remove_stop_words(text):
    words = text.split()
    filtered_words = [word for word in words if word not in stop_words]
    filtered_text = ' '.join(filtered_words)
    return filtered_text

# %%
# Removing the hashtags :
def split_into_sentences(text):
    # Custom sentence splitter based on punctuation marks
    punctuation_marks = ['.', '!', '?']
    sentences = []
    current_sentence = ''

    for char in text:
        current_sentence += char
        if char in punctuation_marks:
            sentences.append(current_sentence.strip())
            current_sentence = ''

    if current_sentence:
        sentences.append(current_sentence.strip())

    return sentences

# %%
def remove_html_symbols(text):
    html_symbols = {
        '&amp;': '&',
        '&lt;': '<',
        '&gt;': '>',
        '&quot;': '"',
        '&apos;': "'"
    }

    result = ""
    i = 0 # index of each char in the words

    while i < len(text):
        if text[i] == '&':
            symbol_found = False

            for symbol in html_symbols:
                if text[i:i+len(symbol)] == symbol:
                    result += html_symbols[symbol]
                    i += len(symbol)
                    symbol_found = True
                    break

            if not symbol_found:
                result += text[i]
                i += 1
        else:
            result += text[i]
            i += 1

    return result

# %%
# removing the cyrillic_letters:
def remove_punctation(text):
    # Define Arabic punctuations
    punctuations = "؟!٪٫٬ـ،؛:\"'(){}[]<>\n"

    # Define Cyrillic letters
    cyrillic_letters = "абвгдежзийклмнопрстуфхцчшщъыьэюя"

    # Remove punctuations and Cyrillic letters from the text
    cleaned_text = ""
    for char in text:
        if char not in punctuations and char not in cyrillic_letters:
            cleaned_text += char

    return cleaned_text

# %%
def remove_tashkeel(text):
    diacritical_marks = [
        '\u064B', '\u064C', '\u064D', '\u064E', '\u064F', '\u0650',
        '\u0651', '\u0652'
    ]

    cleaned_text = ""

    for char in text:
        if char not in diacritical_marks:
            cleaned_text += char

    return cleaned_text

# %%
def remove_urls(text):
    filtered_sentences = []
    sentence = ""

    for char in text:
        # Check if the current character is the end of a sentence
        if char == '.':
            # Remove URLs from the current sentence
            filtered_sentence = remove_urls_from_sentence(sentence)

            # Add the filtered sentence to the list
            filtered_sentences.append(filtered_sentence)

            # Reset the sentence variable for the next sentence
            sentence = ""
        else:
            # Append the character to the current sentence
            sentence += char

    return filtered_sentences


def remove_urls_from_sentence(sentence):
    # Remove words containing 'http://' or 'https://'
    words = sentence.split()
    filtered_words = [word for word in words if 'http://' not in word and 'https://' not in word]
    filtered_sentence = ' '.join(filtered_words)
    return filtered_sentence

# %%
#Remove Numbers
def remove_numbers(text):
    # Create an empty string to store the result
    result = ""

    # Iterate over each character in the text
    for char in text:
        # Check if the character is not a numeric digit
        if not char.isdigit():
            # Append the character to the result string
            result += char

    return result

# %%
#Remove Multiple Whitespace
def remove_multiple_whitespace(text):
    # Create an empty string to store the result
    result = ""

    # Flag to keep track of consecutive whitespace
    is_whitespace = False

    # Iterate over each character in the text
    for char in text:
        # Check if the character is a whitespace
        if char.isspace():
            # Check if it is the first whitespace encountered
            if not is_whitespace:
                # Append a single space to the result string
                result += " "
                is_whitespace = True
        else:
            # Append the character to the result string
            result += char
            is_whitespace = False

    return result

# %%
def extract_arabic_sentences(corpus):
    arabic_sentences = ""
    sentence = ""

    for char in corpus:
        if char == '.':
            sentence += char
            arabic_sentences += sentence.strip() + " "
            sentence = ""
        elif is_arabic_letter(char) or char.isspace():
            sentence += char

    if sentence:
        arabic_sentences += sentence.strip() + " "

    return arabic_sentences.strip()


def is_arabic_letter(char):
    arabic_letters = [
        '\u0621', '\u0622', '\u0623', '\u0624', '\u0625', '\u0626', '\u0627',
        '\u0628', '\u0629', '\u062A', '\u062B', '\u062C', '\u062D', '\u062E',
        '\u062F', '\u0630', '\u0631', '\u0632', '\u0633', '\u0634', '\u0635',
        '\u0636', '\u0637', '\u0638', '\u0639', '\u063A', '\u0641', '\u0642',
        '\u0643', '\u0644', '\u0645', '\u0646', '\u0647', '\u0648', '\u0649',
        '\u064A', '\u064B', '\u064C', '\u064D', '\u064E', '\u064F', '\u0650',
        '\u0651', '\u0652', '\u0670', '\u0671'
    ]

    return char in arabic_letters

# %%
# combining all the pre-processing step in one function:
def clean(text):
    text = extract_arabic_sentences(text)
    text = remove_urls(text)
    text = remove_html_symbols(text)
    text = remove_punctation(text)
    text = remove_numbers(text)
    text = remove_stop_words(text)
    text = remove_multiple_whitespace(text)
    text = remove_tashkeel(text)
    return text

# %%
# Applying the pre-processing on the documents:
df["Cleaned_data"] = df["Article"].apply(clean)

# %%
df.head()
# Out:
#                                              Article  word_count  char_count  \
# 0  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...        1123        6503
# 1  البريد الالكتروني هل نسيت كلمة المرور ؟\nكلمة ...        1331        7460
# 2  قال رئيس مايكروسوفت (Microsoft) براد سميث، الخ...         292        1773
# 3  قالت وكالات استخبار غربية وشركة مايكروسوفت إن ...         580        3669
# 4  استخدم محتال في الصين تقنية الذكاء الاصطناعي ل...         215        1179
#
#                                         Cleaned_data
# 0  البريد الالكتروني نسيت كلمة المرور كلمة المرور...
# 1  البريد الالكتروني نسيت كلمة المرور كلمة المرور...
# 2  قال رئيس مايكروسوفت براد سميث الخميس أكبر مخاو...
# 3  قالت وكالات استخبار غربية وشركة مايكروسوفت مجم...
# 4  استخدم محتال الصين تقنية الذكاء الاصطناعي لتغي...

# %%
#example from the text at cell 2004 :
df.loc[2004,"Cleaned_data"]
# Out:
# 'نتيجة اختفت كيلوغرامات الذهب كان يملكها اختفت بضائع المحال السوقرغم القصف الجوي والمعارك تدور شمال الخرطوم حرص الرجل الذهاب مسكنه الطرف الآخر المدينة منطقة بحري الضفة الأخرى للنيل يقسم العاصمة السودانية للوقوف حدثوتأكد خشي منهيروي عبد الرحمن لفرانس برس نهبوا رأسمالي الحلي الذهبية سرقت يبق شيء مطلقاوبتابع أتمنى تتوقف الحرب نحاول نتدبر أمرنا ونبدأ بداية جديدةولكن توقفت الحرب المستمرة الخامس عشر نيسانإبريل قائد الجيش الفريق أول عبد الفتاح البرهان وقائد قوات الدعم السريع محمد حمدان دقلو اقتصاد السودان أحد أفقر بلدان العالم منكوب عدة عقودبعد عشرين عاما العقوبات الدولية عاد السودان المجتمع الدولي إثر سقوط عمر البشير العامولكن انقلاب العام قام الجنرالان المتحاربان اليوم أدى وقف المساعدات الدولية البالغة ملياري دولار حصلت عليها الخرطوم خلال العامين السابقينوهكذا فقدت الدولة السودانية يوم واحد دخلها وهي قيمة المساعدات الدولية كانت تعاني بالفعل الفساد آثار العقوبات الدولية واستقلال جنوب السودان العام أدى خسارة الخرطوم تقريبا حقول النفطولم تعلن السلطات السودانية موازنة العام ولكنها أشادت بتراجع التضخم الويقول الخبراء التراجع يكن بسبب تحسن الوضع ناتج ركود كبيرومع احتفظت الخرطوم قبل اندلاع الحرب بمظاهر تحسن للوضع الاقتصادي تتمثل مطاعم دولية تقدم أطباقا صديقة للبيئة ومتاجر مليئة بالمنتجات الأميركية الواردة العاصمة السودانية غالبا خلال طرق التهريب دول الساحلاليوم أنحاء الخرطوم يقطنها خمسة ملايين نسمة باتت الأبواب الزجاجية لمعارض السيارات وواجهات محال الأجهزة المنزلية الكهربائية المهشمة وأبواب المحال الصغيرة كسرت أقفالها شاهدا حجم عمليات النهبمطار الخرطوم توقف العمل بدء المعارك وميناء بورتسودان الرئة الاقتصادية للبلاد البحر الأحمر يعد يصله السفن والطائرات تنقل مدنيين يفرون الحرب مساعدات إنسانيةولم تنج عمليات النهب المستشفيات المنظمات الإنسانية المنازل تركها ألف سكانها الخرطوم بسبب القتال وفروا مدن أخرى الدول المجاورةنور الدين آدم صاحب محل لبيع الهواتف النقالة وسط الخرطوم بحري يقول تم كسر قفل المحل خمسة أيام بداية القتال ونهبوا البضاعة ولم يتركوا شيئاويضيف صرت أملك راسمال إنني مدين لبعض التجار أعرف سأسدد المديونيةوقال موظف طالبا عدم الكشف هويته تم نهب البضائع الموجودة محطة حاويات سوبا جنوب الخرطوموأوضح بضائع استوردها أصحابها ولم يكملوا إجراءات تخليصها جمركيا بسبب الحربوفي المنطقة الصناعية بالخرطوم بحري أكد شهود عيان مخزن مطحنة سيقا لدقيق القمح تعرض للنهب وهي أكبر مطحنة البلاد زاد أزمة الخبز بلد يعاني مليونا سكانه البالغ عددهم مليونا الجوع ستة أشهر استمرت الحربعمر عبد الدايم مر يفتح الآخر محل الملابس يملكه سوق الخرطوم بحري مجدداويروي عمر أنه ثالث أيام الحرب سقطت قذيفة السوق واشتعلت النيران المحالبعضها احترق تماما والبعض الآخر جزئيا تبقى تم نهبه وهذا حدث لمحليويضيف السبب ببساطة أنه تكن حراسة الشرطة الرغم رئاسة شرطة بحري مقرها داخل السوقفرانس برس نستخدم ملفات تعريف الارتباط كوكيز خاصة وتابعة لأطراف ثالثة لدراسة و تحليل استخدام الموقع الالكتروني وتحسين خدماتنا و وظائف الموقعبمواصلة فإنك توافق استخدام ملفات تعريف الارتباط كوكيز وعلى سياسة'

# %% [markdown]
# # Finding the similarity of the cleaned data :
#
# ---

# %% [markdown]
# ### Similarity using TF_IDF vectors:

# %%
def get_word_counts(document):
    # Convert the document to lowercase and tokenize it
    words = re.findall(r'\w+', document.lower())
    # Count the occurrences of each word
    word_counts = Counter(words)
    return word_counts

def get_tfidf_vector(word, corpus):
    # Calculate the term frequency (TF) for the given word in each document
    tf_values = []
    for document in corpus:
        word_counts = get_word_counts(document)
        word_count = word_counts.get(word, 0)
        tf = word_count / len(word_counts) if len(word_counts) > 0 else 0
        tf_values.append(tf)

    # Calculate the inverse document frequency (IDF) for the given word
    num_documents = len(corpus)
    num_documents_with_word = sum(1 for document in corpus if word in get_word_counts(document))
    idf = math.log(num_documents / (1 + num_documents_with_word))

    # Calculate the TF-IDF values
    tfidf_values = [tf * idf for tf in tf_values]

    return tfidf_values

# %%
# Prompting the words:
corpus = df['Cleaned_data']
word1 = input("Enter word 1: ")
word2 = input("Enter word 2: ")
tfidf_value1 = get_tfidf_vector(word1, corpus)
tfidf_value2 = get_tfidf_vector(word2, corpus)
# Out:
# Enter word 1: الحاسوب
# Enter word 2: الذكاء

# %%
# Reshaping the vectors:
x1 = np.array(tfidf_value1).reshape(1, -1)
x2 = np.array(tfidf_value2).reshape(1, -1)
cosine_sim = cosine_similarity(x1,x2)
print(cosine_sim)
# Out:
# [[0.04243516]]

# %% [markdown]
# # Finding similarity using word embedding with bert:
#
# ---

# %%
# Load the data into a list
corpus = df["Cleaned_data"]

# Load the pre-trained BERT model and tokenizer
model_name = "bert-large-uncased"    #2
#model_name = "aubmindlab/bert-base-arabert"    #1
#model_name = "bert-base-multilingual-cased"
#model_name = "UBC-NLP/ARBERT"
#model_name = "asafaya/bert-base-arabic"
#model_name = "aubmindlab/bert-base-arabertv2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Tokenize the words in the corpus
tokenized_words = [tokenizer.tokenize(word) for word in corpus]
print(tokenized_words[:10])
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Token indices sequence length is longer than the specified maximum sequence length for this model (4090 > 512). Running this sequence through the model will result in indexing errors
# [['ا', '##ل', '##ب', '##ر', '##ي', '##د', 'ا', '##ل', '##ا', '##ل', '##ك', '##ت', '##ر', '##و', '##ن', '##ي', 'ن', '##س', '##ي', '##ت', 'ك', '##ل', '##م', '##ة', 'ا', '##ل', '##م', '##ر', '##و', '##ر', 'ك', '##ل', '##م', '##ة', 'ا', '##ل', '##م', '##ر', '##و', '##ر', 'ا', '##ظ', '##ه', '##ا', '##ر', 'ت', '##ذ', '##ك', '##ر', '##ن', '##ي', 'ا', '##ل', '##ا', '##س', '##م', 'ا', '##ل', '##ا', '##و', '##ل', 'ا', '##ل', '##ا', '##س', '##م', 'ا', '##ل', '##ا', '##خ', '##ي', '##ر', 'ا', '##ل', '##ب', '##ر', '##ي', '##د', 'ا', '##ل', '##ا', '##ل', '##ك', '##ت', '##ر', '##و', '##ن', '##ي', 'ك', '##ل', '##م', '##ة', 'ا', '##ل', '##م', '##ر', '##و', '##ر', 'ا', '##ظ', '##ه', '##ا', '##ر', 'ف', '##ق', '##د', '##ت', 'ك', '##ل', '##م', '##ة', 'ا', '##ل', '##م', '##ر', '##و', '##ر', 'ا', '##ل', '##خ', '##ا', '##ص', '##ة', 'ي', '##ر', '##ج', '##ى', 'ا', '##د', '##خ', '##ا', '##ل', 'ع', '##ن', '##و', '##ان', 'ب', '##ر', '##ي', '##د', '##ك', 'ا', '##ل', '##ا', '##ل', '##ك', '##ت', '##ر', '##و', '##ن', '##ي', '##س', '##و', '##ف', 'ت', '##ت', '##ل', '##ق', '##ى', 'ا', '##ر', '##ت', '##ب', '##ا', '##ط', '##ا', 'ل', '##ان', '##ش', '##ا', '##ء', 'ك', '##ل', '##م', '##ة', 'م', '##ر', '##و', '##ر', 'ج', '##د', '##ي', '##د', '##ة', '##ا', '##ل', '##ب', '##ر', '##ي', '##د', 'ا', '##ل', '##ا', '##ل', '##ك', '##ت', '##ر', '##و', '##ن', '##ي', 'ا', '##س', '##ب', '##و', '##ع', 'ا', '##خ', '##ر', 'ب', '##ت', '##ا', '##ر', '##ي', '##خ', 'ا', '##ل', '##ا', '##ش', '##ه', '##ر', 'ا', '##ل', '##ق', '##ل', '##ي', '##ل', '##ة', 'ا', '##ل', '##م', '##ا', '##ض', '##ي', '##ة', 'ا', '##ش', '##ت', '##ع', '##ل', '##ت', 'ث', '##و', '##ر', '##ة', 'ا', '##ل', '##ذ', '##ك', '##ا', '##ء', 'ا', '##ل', '##ا', '##ص', '##ط', '##ن', '##ا', '##ع', '##ي', 'ظ', '##ه', '##و', '##ر', 'ا', '##ل', '##ع', '##د', '##ي', '##د', 'ا', '##ل', '##ر', '##و', '##ب', '##و', '##ت', '##ا', '##ت', 'ا', '##ل', '##ر', '##ا', '##ي', '##ع', '##ة', 'ي', '##م', '##ك', '##ن', '##ه', '##ا', 'ا', '##ل', '##د', '##خ', '##و', '##ل', 'م', '##ح', '##ا', '##د', '##ث', '##ا', '##ت', 'و', '##ن', '##ق', '##ا', '##ش', '##ا', '##ت', 'و', '##ا', '##ع', '##ط', '##ا', '##ء', 'ا', '##ج', '##ا', '##ب', '##ا', '##ت', 'م', '##ن', '##ط', '##ق', '##ي', '##ة', 'و', '##ذ', '##ك', '##ي', '##ة', 'خ', '##ل', '##ا', '##ل', 'ق', '##ا', '##ع', '##د', '##ة', 'ا', '##ل', '##ب', '##ي', '##ان', '##ا', '##ت', 'ا', '##ل', '##خ', '##ا', '##ص', '##ة', 'و', '##ا', '##ل', '##ت', '##ي', 'ت', '##ح', '##ت', '##و', '##ي', 'ا', '##ل', '##ك', '##ث', '##ي', '##ر', 'و', '##ا', '##ل', '##ك', '##ث', '##ي', '##ر', 'ا', '##ل', '##م', '##ع', '##ل', '##و', '##م', '##ا', '##ت', 'ا', '##ل', '##ن', '##ص', '##ي', '##ة', '##ه', '##و', 'و', '##ا', '##ح', '##د', 'ا', '##ه', '##م', 'ا', '##م', '##ث', '##ل', '##ة', 'ن', '##م', '##ا', '##ذ', '##ج', 'ا', '##ل', '##ذ', '##ك', '##ا', '##ء', 'ا', '##ل', '##ا', '##ص', '##ط', '##ن', '##ا', '##ع', '##ي', 'ا', '##ل', '##ل', '##غ', '##و', '##ي', '##ة', 'ت', '##ع', '##ر', '##ف', 'ب', '##ر', '##و', '##ب', '##و', '##ت', '##ا', '##ت', 'ا', '##ل', '##د', '##ر', '##د', '##ش', '##ة', '##و', '##ت', '##س', '##ت', '##خ', '##د', '##م', 'ا', '##ل', '##ر', '##و', '##ب', '##و', '##ت', '##ا', '##ت', 'ق', '##و', '##ا', '##ع', '##د', 'ب', '##ي', '##ان', '##ا', '##ت', '##ه', '##ا', 'ب', '##ش', '##ك', '##ل', 'م', '##ش', '##ا', '##ب', '##ه', 'ل', '##ع', '##م', '##ل', '##ي', '##ة', 'ا', '##ل', '##ت', '##ف', '##ك', '##ي', '##ر', 'د', '##ا', '##خ', '##ل', 'ع', '##ق', '##ل', 'ا', '##ل', '##ان', '##س', '##ان', '##ف', '##ه', '##ي', 'ت', '##ب', '##ح', '##ث', 'ا', '##ج', '##ا', '##ب', '##ة', 'و', '##س', '##ط', 'ا', '##ل', '##س', '##ط', '##و', '##ر', 'ا', '##ل', '##م', '##ك', '##ت', '##و', '##ب', '##ة', 'د', '##ا', '##خ', '##ل', 'ق', '##ا', '##ع', '##د', '##ة', 'ب', '##ي', '##ان', '##ا', '##ت', '##ه', '##ا', 'ك', '##م', '##ح', '##ر', '##ك', '##ا', '##ت', 'ا', '##ل', '##ب', '##ح', '##ث', 'م', '##ث', '##ل', '##ا', 'و', '##ان', '##م', '##ا', 'ت', '##ع', '##ت', '##م', '##د', 'ا', '##ل', '##ت', '##ن', '##ب', '##و', 'و', '##ت', '##ج', '##م', '##ي', '##ع', 'ص', ' ...

# %%
# Generate word embeddings to the words:
def generate_word_embeddings(words):
    # Convert the words to input tensors
    inputs = tokenizer(words, padding=True, truncation=True, return_tensors="pt")

    # Get the BERT embeddings
    with torch.no_grad():
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state.mean(dim=1)  # Average over the tokens

    # Convert the embeddings to a numpy array
    word_embeddings = embeddings.numpy()

    return word_embeddings

# Prompting the two words
word1 = input("Enter word 1: ")
word2 = input("Enter word 2: ")

# Generate embeddings for the prompted words
word_embeddings = generate_word_embeddings([word1, word2])
word1_embeddings = word_embeddings[0]
word2_embeddings = word_embeddings[1]

# Calculate the similarity between the embeddings
similarity_score = cosine_similarity([word1_embeddings], [word2_embeddings])[0][0]
print(f"Similarity between '{word1}' and '{word2}': {similarity_score}")
# Out:
# Enter word 1: الحاسوب
# Enter word 2: الذكاء
# Similarity between 'الحاسوب' and 'الذكاء': 0.8850722312927246

# %% [markdown]
# # Search Engine part:
#
# ---

# %% [markdown]
# search for the prompted word in the corpus then return the articles that have the word back with its index.
# Then, count the total occurrence of that word:

# %%
# Arabic documents
documents = df['Cleaned_data']

# Function to perform Arabic search
def search(query):
    results = []
    for i, document in enumerate(documents):
        if re.search(query, document, re.UNICODE):
            results.append(i)
    return results

# User input for search query
query = input("Enter Arabic search query: ")

# Applying the function that perform search
results = search(query)

# Display search results
if results:
    print("Search Results:")
    for idx in results:
        print(f"Document {idx + 1}: {documents[idx]}")
else:
    print("No results found.")

# Function that count the occurrence of the word
def search(query):
    count = 0
    for document in documents:
        matches = re.findall(query, document, re.UNICODE)
        count += len(matches)
    return count

# Perform occurence count
count = search(query)

# Display search results
print(f"Total occurrences of '{query}': {count}")

# %% [markdown]
# Search engine with a specified number of articles to display:

# %%
# Arabic documents
documents = df['Cleaned_data']

# Function to search and specify the number of save articles containing the word
def search_and_save(query, num_articles):
    results = []
    count = 0
    for i, document in enumerate(documents):
        if re.search(query, document, re.UNICODE):
            results.append(document)
            count += 1
        if count == num_articles:
            break
    return results

# User input for word and number of articles
query = input("Enter Arabic word: ")
num_articles = int(input("Enter the number of articles to save: "))

# Search and save articles
articles = search_and_save(query, num_articles)

# Display the saved articles
print(f"Saved Articles with '{query}' (up to {num_articles} articles):")
for i, article in enumerate(articles):
    print(f"Article {i + 1}:")
    print(article)
    print("-------------------------")

# Function that count the occurrence of performed search
def search(query):
    count = 0
    for document in documents:
        matches = re.findall(query, document, re.UNICODE)
        count += len(matches)
    return count

# Perform search
count = search(query)

# Display search results
print(f"Total occurrences of '{query}': {count}")
# Out:
# Enter Arabic word: الحاسوب
# Enter the number of articles to save: 10
# Saved Articles with 'الحاسوب' (up to 10 articles):
# Article 1:
# أعلنت شركة آبل إطلاق الإصدارات الجديدة برنامج تحرير الفيديو فاينال كت برو وبرنامج الموسيقى لوجيك برو لحواسيب آيباد اللوحيةوأوضحت الشركة الأميركية التطبيقات الجديدة تأتي بواجهة مستخدم معدلة تماما وقد انصب اهتمام الشركة تسهيل استعمال التطبيقات المعقدة الحواسيب اللوحيةوأشارت آبل الإصدار الجديد برنامج فاينال كت برو يتضمن ميزة تمرير افتراضية جديدة تسمى جوغ وييل تتيح للمستخدم التنقل المخطط الزمني أجل تحرير الصور بشكل مفرد وبدقة عالية بالإضافة وظيفة لايف دراونغ تسمح بالرسم فوق محتوى الفيديو مباشرة قلم آبلويتيح وضع الكاميرا الاحترافي إمكانية تسجيل مقاطع فيديو مباشرة كاميرا الحاسوب اللوحي بالتنسيق العمودي الأفقي إمكانية التحكم اليدوي درجة الوضوح والتعريض وتوازن اللون الأبيض مباشرةولا تقتصر المزايا الجديدة برنامج الموسيقى لوجيك برو إمكانية مزج التسجيلات الموجودة ومسارات الصوت فحسب يوفر التطبيق الجديد أيضا أدوات برمجية وتأثيرات وآلات إيقاع وآلات توليف يمكن استعمالها طريق اللمسويقوم تطبيق لوجيك برو الجديد بإظهار الأدوات والتصحيحات والإعدادات المسبقة والعينات والحلقات المتاحة ملف مركزي جديد يحمل اسم متصفح الصوت يمكن للمستخدم تشغيل الصوت والاستماع إليه بنقرة الزر قبل الحاجة تنزيل ملف المشروع كاملاوبطبيعة الحال يمكن استعمال الميكروفون المدمج الحاسوب اللوحي آيباد لتسجيل الأصوات والآلاتويشتمل إصدار آيباد برو ميكروفونات لتوفير تسجيل بجودة الأستوديووأعلنت شركة آبل طرح الإصدارات الجديدة بدءا مايوأيار الجاريوتتطلب البرامج الجديدة توفر نظام تشغيل حديث بدءا إصدار آيباد إسويحتاج برنامج فاينال كت برو توافر معالج إم الأقل حاسوب آيباد اللوحي برنامج لوجيك برو فإنه يتطلب المعالج بيونيك الأقل
# -------------------------
# Article 2:
# أطلقت شركة أوبن مطورة برنامج دردشة الذكاء الاصطناعي الشهير شات جي أمس الخميس تطبيق شات جي لنظام التشغيل إس آبل حسب تقرير لوكالة رويترزوقالت أوبن استخدام تطبيق شات جي سيكون مجانيا وسيعمل جهاز بحساب واحدوأضافت الشركة مشتركي شات جي بلس إس سيستفيدون حصريا إمكانيات جي الوصول المبكر الميزات وفي أوقات استجابة أسرعوأطلقت شركة أوبن وقت سابق فبرايرشباط الماضي خطة اشتراك تجريبية لبرنامج الدردشة الشهير يعمل بالذكاء الاصطناعي يطلق شات جي بلس مقابل دولارا شهرياوقالت الشركة إنها بدأت طرحه نظام إس الولايات المتحدة وستتوسع دول أخرى الأسابيع المقبلةوانطلقت المعركة الكبيرة للسيطرة تكنولوجيا الذكاء الاصطناعي أواخر العام الماضي إطلاق شات جي ودفعت الشركات التكنولوجية الكبيرة مثل ألفابت وميتا الترويج لمنتجاتها الخاصةوحسب الإعلان الرسمي التطبيق متاح فقط للمستخدمين داخل الولايات المتحدة محرر صفحة تكنولوجيا جرب تحميل التطبيق متجر آبل قطر وكان الأمر غاية السهولة نعلم كان متوفرا دول أخرى لاوجود التطبيق هاتفك الذكي يعتبر بحد ذاته تطورا كبيرا يلفت الانتباه خاصية تحويل الصوت كتابة وهي خاصية يمتاز التطبيق البرنامج الموجود الحاسوب وهذه التقنية تفتح الباب للعديد الاستعمالاتعند الدخول للتطبيق تلاحظ أنه سهل الاستخدام وتستطيع تجد ملفات محادثاتك السابقة قمت بإنشائها البرنامج خلال الذهاب أيقونة النقاط الثلاث الموجودة أعلى يمين الشاشة وعند الضغط عليها تظهر قائمة بسيطة أقسام ويمكن للمستخدم لديه اشتراك شهري شات جي بلس يختار بناء المحادثة الجديدة باستخدام النسخة الجديدة شات جي وهي جي النسخة الأقدم وهي جي تيوذلك خلال الجزء العلوي الشاشة يظهر اسم النسختين
# -------------------------
# Article 3:
# قال معظم الأميركيين شملهم استطلاع أجرته رويترز بالتعاون إبسوس وهي شركة عالمية متعددة الجنسيات لأبحاث السوق ومقرها العالمي باريس النمو السريع لتكنولوجيا الذكاء الاصطناعي يعرض مستقبل البشرية للخطرويقول التقرير ثلثي الأميركيين يشعرون بالقلق إزاء الآثار السلبية للذكاء الاصطناعي ويعتقد منهم أنه يمكن يهدد الحضارةومنذ أصبح روبوت الدردشة شات جي شركة أوبن التطبيق الأسرع نموا الإطلاق دفع السباق المحموم لدمج للذكاء الاصطناعي الحياة اليومية تتصدر التكنولوجيا الخطاب العاموأعلن إطلاق شات جي سباقا للتسلح بالذكاء الاصطناعي تتنافس شركات التكنولوجيا الكبيرة مثل مايكروسوفت وغوغل إنجازات الذكاء الاصطناعيوتم إجراء استطلاع رويترزإبسوس عبر الإنترنت وشمل بالغا الولايات المتحدة الفترة و مايوأيار الجاري ووجد عدد الأميركيين يتوقعون نتائج سلبية الذكاء الاصطناعي أضعاف عدد يتوقعون ذلكووفقا للبيانات يعتقد المستطلعين الذكاء الاصطناعي يشكل مخاطر البشرية بينما يوافق وظل متأكدينوأعرب صوتوا للرئيس الأميركي السابق دونالد ترامب انتخابات مستويات أعلى القلق فقد وافق منهم مقارنة ب ناخبي الرئيس الحالي جو بايدن الذكاء الاصطناعي يمكن يهدد البشريةوعندما يتعلق الأمر بالمعتقدات الدينية كان المسيحيون الإنجيليون ميلا الموافقة بشدة الذكاء الاصطناعي يمثل مخاطر البشرية بلغت نسبتهم مقارنة ب المسيحيين الإنجيليينوقال لاندون كلاين مدير السياسة الأميركية معهد مستقبل الحياة ننظر اللحظة الحالية غرار بداية العصر النووي ونستفيد التصور العام يتماشى الحاجة اتخاذ إجراءوأطلق معهد مستقبل الحياة خطابا مفتوحا يطالب بوقف أبحاث الذكاء الاصطناعي بشكل مؤقت ولمدة أشهر ووقع الخطاب عدد المهتمين بمسألة الذكاء الاصطناعي ضمنهم إيلون ماسك الرئيس التنفيذي لشركة تسلاويشعر المشرعون وشركات الذكاء الاصطناعي بالقلق أيضا فقد أدلى سام ألتمان الرئيس التنفيذي لشركة أوبن بشهادته أول أمس الثلاثاء أمام الكونغرس الأميركي معربا مخاوفه بشأن إساءة الاستخدام المحتملة للتكنولوجيا وطالب باتخاذ إجراءات تنظيميةوقال السيناتور كوري بوكر أحد المشرعين الكثيرين كان لديهم أسئلة حول أفضل السبل لتنظيم الذكاء الاصطناعي خلال جلسة مجلس الشيوخ توجد طريقة لوضع الجني الزجاجةهذه التكنولوجيا تنتشر عالمياوبينما يشعر الأميركيون بالقلق بشأن الذكاء الاصطناعي تحتل الجريمة والاقتصاد مرتبة أعلى قائمة القضايا الخطيرة المعروضة الطاولة يؤيد زيادة تمويل الشرطة لمكافحة الجريمة وقد عبر قلقهم خطر الركود وفق استطلاع رويترزإبسوسويرى العاملون صناعة الذكاء الاصطناعي الجمهور يجب يفهم فوائد الذكاء الاصطناعي أكثروقال سيباستيان ثرون أستاذ علوم الحاسوب جامعة ستانفورد المخاوف مشروعة للغاية لكنني أعتقد ينقص الحوار بشكل عام لماذا نفعل المقام الأول سيعمل الذكاء الاصطناعي رفع جودة حياة الناس ومساعدتهم يكونوا كفاءةوقال أيون ستويكا الأستاذ بجامعة كاليفورنيا بيركلي شارك أيضا تأسيس شركة آني سكيل للذكاء الاصطناعي التطبيقات الإيجابية للذكاء الاصطناعي مثل إحداث ثورة اكتشاف الأدوية مرئية مثل شات جي تيوأضاف يدرك الأميركيون مدى انتشار الذكاء الاصطناعي حياتهم اليومية سواء المنزل العمل
# -------------------------
# Article 4:
# أعلنت شركة مايكروسوفت أمس الاثنين أحدث إصدار برنامج فون لينك لأجهزة الحاسوب تعمل بنظام ويندوز يمكنه الآن تلقي الإشعارات وإرسال الرسائل النصية والرد المكالمات هواتف آيفونوفون لينك تطبيق طورته مايكروسوفت للحواسيب تعمل بنظام ويندوز فما فوق ويتيح ربط هواتف المستخدمين تعمل بنظام أندرويد بالحاسوب والوصول الصور الموجودة هواتفهم والرد مكالمات الهاتف والوصول الرسائل وغيرها خلال الحاسوبويستخدم معظم الأميركيين أجهزة آيفون وقد ساعد ترابط منتجات شركة آبل بعضها الحصول حصة سوقية أجهزة الحاسوب الشخصية تعمل بنظام ويندوز السنوات الأخيرة حسب ذكر تقرير لموقع سي سيفقد استحوذت شركة آبل شحنات أجهزة الحاسوب العالمية العام الماضي وفقا لمؤسسة دي سي المختصة بأبحاث السوقويمكن لخطوة مايكروسوفت تزيل عائقا أمام مشتري أجهزة الحاسوب كانوا سيختارون جهاز ماك ليتكامل هواتفهم نوع آيفون كان برنامج فون لينك يعمل سابقا فقط هواتف آندرويدووفقا لتقرير موقع فيرج ينقص برنامج فون لينك العديد الميزات المتوفرة برامج آبل مثل رسائل آبل ويعمل خلال البلوتوث ويتطلب آيفون تثبيت تطبيق لينك تو ويندوز مايكروسوفت قبل البدء باستخدامهيتلقى جهاز الكمبيوتر الشخصي يعمل بنظام ويندوز ويتوفر برنامج فون لينك إشعارات جهاز آيفون الخاص بالمستخدم ويعرض الرسائل ترد ولكنه يستطيع استقبال وقراءة الرسائل الجماعية خلال برنامج مسج المتاح آيفون يسمح للمستخدمين بإرسال الصور مقاطع الفيديوويمكن لفون لينك عرض الرسائل يرسلها يستقبلها فقط لذلك يرى المستخدم أرسل الرسائل النصية هاتفه الجزء سجل رسائله تطبيق فون لينك
# -------------------------
# Article 5:
# أتاحت شركة غوغل إمكانية تسجيل الدخول الحسابات كلمة مرور لجميع مستخدميهاوأطلقت الشركة الأميركية الوظيفة اسم باس كيز تعتمد معيار الأمان العالمي المسمى فيدو للتغلب هجمات تصيد البياناتتعتمد وظيفة تسجيل الدخول كلمة مرور بشكل أساسي يعرف باسم تقنية تشفير المفتاح العام زوجين المفاتيح يتم تخزين المفتاح الخاص المستخدم وتحتفظ الشركة المقدمة للخدمة غوغل الحالة بالمفتاح العامويتم تأمين عملية تسجيل الدخول قبل المستخدم بصمة الأصابع وظيفة التعرف الوجه إدخال رقم بن غرار يحدث المعاملات المصرفية الإنترنتوأشارت غوغل أنه يتم تفعيل وظيفة باس كيز إعدادات حساب غوغل بالإضافة أنه يجب يدعم المتصفح ونظام التشغيل الوظيفةوأعلنت الشركة الأميركية متصفح غوغل كروم يدعم الوظيفة الجديدة فترة ويسري الأمر نفسه نظام تشغيل غوغل أندرويد بدءا الإصدار يمكن للمستخدم تخزين مفاتيح باس كيز مدير كلمات المرور بحساب غوغل ويتيح مدير كلمات المرور أيضا إمكانية النسخ الاحتياطي لوظيفة باس كيز ومزامنتها أجهزة أندرويد الأخرىوطالما المستخدم يعتمد متصفح غوغل كروم فإنه يمكنه تسجيل الدخول طريق وظيفة باس كيز جهاز تم تحديد البند جهاز وعندئذ يجب مسح كود الاستجابة السريعة الهاتف الذكي المتوافر مفاتيح باس كيز وبعد يمكن تخزين الحاسوب بشكل دائم لإتاحة عملية التسجيل كلمة المروروتدعم شركة مايكروسوفت وظيفة باس كيز لنظام التشغيل ويندوز تدعم شركة آبل الوظيفة لنظامي التشغيل الماك وآي إس عملية تسجيل الدخول تتم بشكل تعقيداويتم تخزين مفاتيح باس كيز تم إنشاؤها أجهزة إس متصفح سفاري أجهزة الماك سلسلة المفاتيح بخدمة الحوسبة السحابية كلودويقوم متصفح كروم بتخزين مفاتيح باس كيز وظيفة ويندوز المعروفة هالو الحواسيب المزودة بنظام مايكروسوفت ويندوزوبالنسبة لمتصفح كروم أجهزة أندرويد فإنه يتم تخزين مفاتيح باس كيز مدير كلمات المرور بحساب غوغلومن المتوقع مزامنة وظيفة باس كيز الأجهزة وجميع أنظمة التشغيل مشكلات وتعد شركة غوغل بأن مستخدمي نظام أندرويد سيتمكنون مستقبلا استعمال تطبيقات الشركات الأخرى لإدارة وظيفة باس كيز غرار يحدث حاليا تطبيقات إدارة كلمات المروروقد يستغرق الأمر الوقت إكمال عمليات التطوير وانتشار وظيفة باس كيز ولذلك شركة غوغل تتيح الوظيفة البداية كأحد الخيارات يمكن للمستخدم مواصلة استعمال كلمات المرور العادية ووظيفة المصادقة ثنائية العامل
# -------------------------
# Article 6:
# عادت غوغل رسميا عالم الأجهزة اللوحية توقفها قبل عام فقد أعلنت الشركة مؤتمرها للمطورين حاسوبها اللوحي بكسل تابلت سيكون متاحا بمبلغ دولارا للطلب المسبق بدءا مايوأيار يبدأ الشحن يونيوحزيران المقبلكان تاريخ غوغل الأجهزة اللوحية سيئا بشكل كبير كان النجاح الحقيقي الوحيد حققته الحاسوب اللوحي نيكسس جهاز لوحي صغير رخيص الثمن كان محبوبا عندما ظهر عاموشهدت السنوات اللاحقة تجربة الشركة الكثير الأفكار حول أجهزة الحاسوب المحمولة تعمل باللمس وإطلاق أجهزة لوحية جديدة بنظام أندرويد كروم إس يستعد نجاح تجربة نكسسبل وصل الأمر إعلان رسمي غوغل بعدم صنع أجهزة لوحية جديدة عامولكن الواضح تغير لأن غوغل قامت مرة أخرى بإطلاق جهاز لوحي تم تصميمه ليكون جيدا لاستخدامات الأشخاص المعتادة مثل مشاهدة الفيديو ممارسة الألعاب بشكل مريحيحتوي بكسل تابلت شاشة إل سي دي مقاس بوصة بقوة بكسل بخلفية لامعةويأتي الجهاز ب ألوان الأبيض والأخضر الداكن والوردي الفاتحوعلى الرغم أنه يبدو وكأنه مصنوع البلاستيك جهاز بكسل تابلت إطار الألومنيوم طبقة طلاء نانوية عكس فعلته غوغل بهاتف بكسل الذكيويأتي العلبة بكسل تابلت وحدة مكبر صوت ممغنطة تؤدي عدة مهام تخزين بكسل تابلت عندما يكون قيد الاستخدام يمكن استخدامها كحامل خلال اجتماعات العمل العائلةعند تثبيته وحدة مكبرات الصوت يبدو جهاز بكسل اللوحي مثل جهاز نست هب ماكس وهي شاشة ذكية بقيمة دولارا أصدرتها غوغل عامولكن فقط الشكل العام فبكسل عبارة جهاز لوحي يعمل بنظام أندرويد وليس شاشة ذكية ويدير برنامجا مختلفا تماما ولديه قدرات مختلفة مقارنة بنست هبومع تثبيت الجهاز اللوحي مكبر الصوت يمكنه عرض شرائح للصور ألبومات صور غوغل الخاصة تماما مثل نست هبويحتوي الجهاز أيضا زر وصول سريع تطبيق غوغل هوم تتمكن التحكم الأجهزة المنزلية الذكية ويمكنه قبول الأوامر الصوتية مسافة لاستعلامات مساعد غوغل استخدام اليدينيحتوي جهاز بكسل تابلت معالج تنسور جي الموجود أيضا هاتف بكسل فولد الجديد وبكسل وبرو تم إصدارهما العام الماضيوهو مقترن ب غيغابايتات ذاكرة الوصول العشوائي و غيغابايتا السعة التخزينيةتقول غوغل البطارية توفر يصل ساعة دفق الفيديو عمليات الشحن وهناك منفذ يو إس سي للشحن السلكي تكن تحمل وحدة مكبر الصوتوهو متوفر فقط بنظام يدعم شبكة واي فاي فقط توجد خيارات شبكات جي إل إيهتزين التابلت مكبرات صوت و ميكروفونات لمكالمات الفيديو وكاميرتان واحدة خلفية بدقة ميغابكسلات الزاوية العلوية اليمنى الجهاز اللوحي وفي المقدمة توجد كاميرا أخرى بدقة ميغابكسلات منتصف الإطار العلوي عندما تمسك الجهاز اللوحي اتجاه أفقيوتم دمج ماسح بصمة الأصبع زر الطاقة لدعم تسجيل الدخول والمصادقة البيومتريةويلاحظ لوحة المفاتيح قلم الشاشة مفقود قائمة الملحقات تصنعها غوغل فهذا الجهاز اللوحي تشتريه ليحل محل الحاسوب المحمول ويمكنك بالطبع إقران لوحة مفاتيح بلوتوث بالجهاز واستخدام أقلام يو إس آيلكن غوغل تنتج أيا الملحقات لذلك ستضطر لشرائها شركات أخرىيعمل بكسل تابلت بنظام أندرويد وسيتم تحديثه أندرويد وقت لاحق العاموقالت غوغل تم تطبيقا خاصا لدعم شاشة بكسل تابلت الأكبر حجماولكن بينما يمكنك تقسيم الشاشة تطبيقين نفس الوقت يحتوي برنامج بكسل تابلت الكثير ميزات الإنتاجية الموجودة الأجهزة المنافسةحيث تقوم سامسونغ وآبل وحتى ون بلس بعمل الكثير لجعل أجهزتها اللوحية ملاءمة لإنجاز العمل مقارنة تقوم أجهزة غوغل الوقت الحاليبكسل تابلت جهاز لوحي مصمم للمهام البسيطة تقوم الأجهزة اللوحية الوقت الحاليفمن المحتمل يحل جهاز بكسل تابلت مكان الحواسيب الأجهزة اللوحية المنافسة مجال إنجاز المهماتولكنه جهاز مناسب كنت ترغب فقط مشاهدة أحدث حلقة مسلسلاتك المفضلة أثناء الجلوس أريكتك الاستمتاع بلعبتك المفضلة المنزل التقيد بجهاز كبير
# -------------------------
# Article 7:
# صممت شركة جيزي آرمز اليابانية نظاما الأطراف الروبوتية الشبيهة بالعنكبوت تتكون أذرع يمكن التحكم قبل المستخدم يرتديهاويمكن ربط الأذرع الروبوتية فصلها استبدالها تماما وقد طورتها الشركة اليابانية بهدف إعادة تعريف طريقة تفاعل البشر الروبوتات والذكاء الاصطناعي وإحداث ثورة فيهاويقول موقع الشركة الويب أصبحت أجسام جيزي الرقمية مهمة لانتشار الروبوتات القابلة للارتداء وهي محور الكثير الأبحاث الآونة الأخيرة ويوضح أذرع جيزي عبارة نظام أطراف روبوتية تتكون قاعدة يمكن ارتداؤها أطراف وأذرع روبوتية قابلة للفصل يمكن التحكم قبل مرتديهاوتم تصميم النظام لتمكين التفاعل الاجتماعي مرتديها واستكشاف التفاعلات الممكنة السايبورغ الرقميةوالسايبورغ مصطلح يطلق كائن يتكون مزيج مكونات عضوية وإلكترونية وسجل أول سايبورغ كائن حي سيبراني بريطانيا عام ويدعى نيل هاربيسونوكان يعاني مرض عمى الألوان لذلك تم وضع هوائي رأسه ليساعده تمييز الألوان طريق ربطه بالحاسوب وسماعات أذن بحيث تنقل عدسة الكاميرا دماغ نيل الصور تقسم ألوانها تنقل عبر السماعات أذنه شكل موجة صوتيةالهدف الأساسي لجيزي آرمز التأكد البشر يمكن يتصرفوا الروبوتات والذكاء الاصطناعي بطريقة تبدو طبيعية ومريحة المكونات الاصطناعية امتدادات للجسم البشري يمهد الطريق لتطوير مستقبل يمكن للبشر والآلات العمل معا بسلاسة ودون عناءتتميز الأطراف الاصطناعية الآلية جيزي آرمز بالمرونة الشديدة يسمح بأداء مجموعة واسعة المهام تتراوح حمل الأغراض المستودعات غرف الجراحة بالمستشفىويتم التحكم الأذرع بسهولة قبل مستخدمها يتيح تشغيل الأطراف بحركاتهم الخاصة وخلق الإحساس بأنها امتداد طبيعي لأجسامهموتستخدم الشركة الذكاء الاصطناعي للتحكم الأذرع الروبوتية المربوطة ظهر المستخدم مثل بدلة الرجل العنكبوتوتدافع الشركة تكامل الإنسان والذكاء الاصطناعي وتفاعلهما بحرية المستقبل وليس استبدال الآخر التفوق عليهوتقول الشركة يميزها غيرها تركيزها سهولة التركيب والاتصال فقد تم تجهيز منتج بأطراف قابلة للفصل يتيح للمستخدمين توصيل يصل أذرع آلية إضافيةولا توفر الوحدة المرونة فحسب تسمح أيضا بالتفاعل كائنات السايبورغ الرقمية الأخرى خلال الاتصالات اللاسلكية والحركات المتزامنة يمكن للمستخدمين التعاون بسلاسة وتشكيل شبكة السايبورغ الرقمية المترابطة القادرة إنجاز المهام المعقدة معا
# -------------------------
# Article 8:
# تتطور تقنية الطائرات المسيرة باستمرار وتعمل الابتكارات الجديدة والاستثمارات الكبيرة جلب المزيد النماذج المتقدمة السوق بضعة أشهروتغطي تكنولوجيا المركبات الجوية المأهولة شيء بدءا الديناميكا الهوائية للطائرة المسيرة والمواد المستخدمة تصنيعها وصولا لوحات الدوائر الكهربائية والشرائح والبرامج تمثل عقول النوع الطائراتووفقا لمعهد بروسبيكتيف إندستري ريسيرش منتجات شركة دي جي الصينية تمثل حصة السوق العالمية وأكثر الصين لتحتل المرتبة الأولى شركات الطائرات المسيرة التجارية العالمية العامويعزو مراقبون هيمنة دي جي العمل المستمر مجال التطوير والابتكار وتزويد طائراتها المسيرة بأحدث التكنولوجيا المتوفرة المجال مثل كاميرات الأشعة تحت الحمراء ونظام تحديد المواقع العالمي جي إس والليزربدأت الشركة البداية ببيع طائرات مسيرة ووحدات تحكم وبحلول عام أطلقت الشركة الطائرة المسيرة دي جي فانتوم أول منتجاتها الموجهة للمستهلكينومثلت الطائرة بداية انتشار الطائرات المسيرة أنحاء العالم زودتها الشركة بنظام تحديد المواقع العالمي كان شحن البطارية يستغرق دقيقة ويمكنها الطيران لمدة دقائق فقطوإلى جانب كانت كاميرا حامل لهاوكان المستخدمين تركيب كاميرا غو برو غيرها الكاميرات خفيفة الوزن يتمكنوا تسجيل اللقطات الجوية الكاميرا المثبتة كانت تعاني الاهتزاز أثناء الطيرانوقبل يتم دمج تقنية نظام تحديد المواقع العالمي الطائرات المسيرة تكن المستخدمين وسيلة طريقة لتحديد اتجاه موقع الطائرات الهواء جعل التحكم الطائرة والمناورة صعبا للغاية وأدت المشكلة إعاقة تجربة المستخدم الإجمالية بشكل كبيروعبر دمج نظام تحديد المواقع العالمي والبوصلة أصبح الممكن للطائرات المسيرة تثبت مكانها ترك المستخدم جهاز التحكم بعدومنح المشغلين التحكم الكامل الطائرات وجعل التكنولوجيا أمانا وأسهل للطيرانوأدى الدمج الداخلي لنظام تحديد المواقع العالمي جعل طائرات دي جي أمانا وموثوقية أثناء الطيران طائرة مسيرة أخرى متاحة الوقتوعملت الشركة تحسين طائرة جديدة تصدرها باستمرار وابتكار تقنيات رئيسية وتحديث المواصفات المدى ووقت الرحلة وجودة الكاميرا جاءت فانتوم فيجن كاميرا مدمجة قادرة تسجيل مقاطع فيديو بدقة بكسلا بمعدل إطارا الثانيةوتميزت فانتوم فيجن بوقت طيران ممتد يصل دقيقة ومدى يصل متر وكانت أول طائرة مسيرة تصدرها دي جي تتضمن كاميرا مدمجة يمكنها التقاط صور ثابتة بدقة ميغابكسلاوواصلت الشركة التطوير وفي غضون شهرين إصدار فانتوم فيجن أصدرت الشركة فانتوم زودتها بكاميرا غو برو ونظام تثبيتكما أصلحت الشركة المرة مشكلات الإصدار السابق زادت دي جي المدى وعمر البطارية يتمكن المستخدمون إبقاء الطائرات الهواء فترة أكبر والطيران لمسافة أطولوسمح للطائرة بالطيران دقيقة مدى يصل متر تضمينها الإصدار الثاني نظام التحكم بالطيران المدمج نازاإم ونظام التحكم العامل بترددغيغاهرتز قناة منفصلة ومنفذ للتحكم بمحور التثبيت زينميز إتش ديوكان مهما لأن المشغلين يعودوا بحاجة جعل الطائرة تهبط أجل استبدال البطارية الحال كثير الأحيان الأمر أدى السابق إعاقة تجربة الطيران الإجمالية بشكل كبيروجلبت فانتوم فيجن الصادرة عام أول نظام تثبيت ثلاثي المحاور مستقر موجود طائرة مسيرة دي جي وساعد الحصول لقطات سلسة وخالية الاهتزازوكان المستخدمين قبل شراء الكاميرا ونظام التثبيت الطيران كاميرا يمكن تميل لأعلى لأسفل فقط بقاء اللقطات عرضة للاهتزازويضمن نظام التثبيت ثلاثي المحاور المتقدم فانتوم فيجن تكون اللقطات سلسة ومستقرة الهواء ومنح الطيارين مزيدا الحرية لتصوير لقطات ديناميكية ومبتكرةكما جاءت الطائرة كاميرا بدقة ميغابكسلا و دقيقة وقت الطيران ومدى يصل متر تقريبا ونظام تحديد مواقع متقدموواصلت دي جي التطوير عام إطلاق سلسلة فانتوم ب إصدارات مختلفة أساسي ومتطور واحترافيوتضمن الإصدار الأساسي كاميرا مدمجة أعيد تصميمها قادرة تصوير مقاطع فيديو بدقةكي بمعدل إطارا الثانية جانب التقاط صور ثابتة بدقة ميغابكسلا بتنسيقات جي جي وراو بمدى كيلومتر و دقيقة وقت الطيرانبينما تميز الإصدار المتطور بمدى ممتد يبلغ كيلومتر و دقيقة وقت الطيران وأول كاميرا بدقة ميغابكسلا تصدرها شركة دي جي آيوكان التحسن الملحوظ الإصدار الأساسي والمتطور دمج النسخة الروسية نظام تحديد المواقع العالمي غلوناس بالإضافة أنظمة تحديد المواقع العالميةوسمح الأمر للطائرة بالاتصال بالمزيد الأقمار الصناعية لتحسين الاستقرار ودقة الموقع أثناء الطيران يجعل الطائرة سهولة وأمانا للقيادة الهواء مقارنة بسابقاتهاوزودت دي جي الإصدار المتطور والاحترافي فانتوم بنظام نقل لايت بريدج المدمج يتيح مدى أطول وقدرة نقل فيديو عالية الدقة تصل كيلومتر واحد وأثبت النظام أنه أفضل بكثير نظام الشبكة اللاسلكية الموجود الإصدار الأساسي فانتوموكان مهما لأن مستخدمي ...
# -------------------------
# Article 9:
# حذر خبير تقني اكتشاف المخترق كلمة مرور واحدة فقط كلمات المرور الخاصة يمكن يكون كافيا لإحداث أضرار جسيمة خاصة كانت كلمة مرور البريد الإلكتروني الخاصة بكونقل تقرير لصحيفة ديلي ميل البريطانية أخصائي الأمن السيبراني شركة إيسيت جيك مور قوله السهل جدا مجرمي الإنترنت الحصول كلمة مرورويعتاش مجرمو الإنترنت اختراق قاعدة بيانات الشركات الكبيرة تحتوي كلمات مرور مخزنة الاستفادة معلومات وإجراءات الأمن الداخلي موظفي شركةوهناك طريقة أخرى لسرقة كلمات المرور وهي رسائل البريد الإلكتروني المخادعة تحتوي روابط تؤدي مواقع ويب مزيفة مصممة لخداعك لإدخال كلمة مروركولكن الطريقة الأسهل والأغرب كثير الحالات قدرة المخترقين تخمين كلمة المرور بسهولة لأنها تتكون كلمات عبارات شائعة وسهلة مثل تاريخ معين كلمات سر شائعة مثلوقال مور أحد أكبر المخاطر الناس لديهم عادة سيئة استخدام كلمة المرور نفسها لعدة حسابات مختلفةلذلك كان أحد المتسللين يعرف عنوان بريدك الإلكتروني وكلمة المرور لحساب واحد فسيجرب المعلومات عدة أنظمة مختلفة أيضاوكشف مور الضرر يمكن يحدث حصل المتسلل كلمة مرور حالات مختلفةيقول الخبير المحتمل يكون الضرر الأكبر حصل المجرم كلمة مرور بريدك الإلكتروني لأن الوصول البريد الإلكتروني يمكن يكون بوابة للدخول العديد المنصات الأخرىوأضاف البريد الإلكتروني الحساب الأكثر إثارة للقلق يمكن للمستخدم يفقد السيطرة لأنه تم اختراقه فيمكن للمتسللين ببساطة الوصول الحسابات الأخرى عبر الإنترنتوتحتوي حسابات البريد الإلكتروني مثل جميل أيضا قدر كبير المعلومات الشخصية المخزنة يمكن استخدامها لاختراقك مثل تاريخ الميلاد ورقم الهاتف وحتى عنوان المنزلعلاوة يتم تخزين كلمات المرور الخاصة بمواقع الويب المختلفة حساب غوغل الخاص يمكن الوصول إليه طريق تسجيل الدخول جميلوقال مور كان أحد المتسللين لديه حق الوصول جميل الخاص المحتمل يتمكن أيضا الوصول حسابات غوغل المتصلة بهيتضمن حساب تويتر الخاص رقم هاتفك وعنوان بريدك الإلكتروني والمزيد تاريخ ميلادك وأيضا تفاصيل الدفع الخاصة كنت مشتركا تويتر بلولكن يمكن للمخترق أيضا تجديد حسابك لانتحال شخصية شخص وهي عملية تخريب لأنه يمكن لموظفي تويتر ملاحظة وحظر حسابك يعني فقدانه للأبدويعتمد الكثير أمن حسابات التواصل الاجتماعي معيار أمان معروف باسم المصادقة الثنائية إف يتم إعداده حسابكيرسل معيار الأمان رسالة نصية قصيرة تحتوي رمز الهواتف الذكية للمستخدمين يتعين عليهم إدخالها للوصول حساباتهم كطبقة إضافية الأمانوقام إيلون ماسك مؤخرا بإزالة المصادقة الثنائية للرسائل النصية القصيرة الإصدار المجاني تويتر وجعلها حصرية لمشتركي تويتر بلو قرار وصفه مور بالسخيف لأنه سيؤدي اختراق العديد الحساباتومع يمكنك استخدام تطبيق مصادقة مثل غوغل أوثنتيكاتر للاستمرار استخدام المصادقة الثنائية حساب تويتر الخاص بكوفي الوقت نفسه حصل أحد المتطفلين كلمة مرور فيسبوك الخاصة فستكون خطوتهم التالية الأرجح مشاركة روابط البريد العشوائي والتصيد الاحتيالي أصدقائك يؤدي اختراق حسابك مرة أخرىبينما يستخدم المجرمون حسابات مزيفة لإجراء عمليات التصيد الاحتيالي يفضلون بشكل متزايد اختراق الحسابات المشروعةوقال مور تطبيقات التسوق عبر الإنترنت تخزن المعلومات الشخصية المحمية فقط بكلمة مرورومما يدعو للقلق استخدام التطبيقات لمعرفة تفاصيلك الشخصية الخاصة يمكن بيعها الويب المظلمولا يمكن الوصول الويب المظلم خلال متصفحات الويب الخاصة ويتم استخدامه لإبقاء نشاط الإنترنت مجهول الهوية لذا فهو بالنسبة للمجرمين مكان مثالي لنشاطهم القانونيوقال مور المعلومات الذهب الجديد والتي يمكن شراؤها وبيعهايمكن للقراصنة استخدام معلوماتك المسروقة لفتح حسابات بطاقة الائتمان والتقدم بطلب للحصول مزايا حكومية والحصول قروض باسمك وغير الكثيربشكل عام يوصي مور باستخدام مديري كلمات المرور وهي التطبيقات الموجودة هاتفك جهازك اللوحي الحاسوب يخزن كلمات المرور الخاصة تحتاج تذكرهاوقال مور يكاد يكون المستحيل اختراق مديري كلمات المرور ستحتاج جهاز معتمد لرؤية كلمات المرور مؤكدا ضرورة يتم تحديد المعلومات خزنتها عبر الإنترنت وتقديم البيانات الضرورية فقط للتطبيق الخدمة
# -------------------------
# Article 10:
# يعد مستخدمو تطبيق واتساب مجبرين استخدام حساباتهم هاتف واحد فقط الحساب نفسه بات متاحا أجهزة متعددة الوقت ذاتهوأعلن مارك زوكربيرغ رئيس شركة ميتا المالكة لتطبيق واتساب أنه بدءا أمس الثلاثاء يمكن للمستخدمين تسجيل الدخول حساب واتساب الخاص هواتف إضافية للهاتف الرئيسييمكن لمستخدمي واتساب الآن ربط هواتف ذكية إضافية طريق مسح رموز كيو آر باستخدام هواتفهم الأساسية ففي السابق كان يستطيع المستخدمون بالفعل توصيل يصل أجهزة حاسوب أجهزة لوحية بحساب واتساب واحد الآن أصبح يمكنهم تسجيل الدخول عبر الهواتف أيضاستناسب الميزة طال انتظارها لديهم هاتف للعمل وآخر للاستخدام الشخصي ولكنهم يفضلون تكون محادثاتهم ضمن حساب واتساب واحدوقالت واتساب بدأ طرح التحديث للمستخدمين مستوى العالم وسيكون متاحا للجميع خلال الأسابيع المقبلةوتفاديا لاختراق الحسابات الخاصة قالت واتساب يمكن للمستخدمين التحقق أجهزة أخرى متصلة بحساباتهم وتسجيل خروجهم بعد هواتفهمويعمل واتساب تم إصداره لأول مرة عام إرسال الرسائل النصية عبر الإنترنت ولهذا السبب كان حساب واتساب مرتبطا دائما بشكل وثيق برقم هاتف فردي الرغم أنه أصبح الممكن مؤخرا فتحه عديد الأجهزة الهاتفيةوعام بدأ واتساب السماح للمستخدمين بتوصيل يصل أجهزة إضافية هاتفية مثل أجهزة الحاسوب والأجهزة اللوحية بحساباتهم بشكل مستقل الهاتف وهذا يعني المستخدم كان قادرا تشغيل هاتفه وجهازين لوحيين وجهازي حاسوب جميعا بحساب واتساب الفرديوتم طرح الميزة مستوى العالم بحلول عام واتساب الآن تخطو خطوة الأمام خلال تقديم القدرة استخدام حساب واتساب واحد هواتف متعددة أيضاوقالت واتساب جهاز سيتصل بواتساب بشكل مستقل يضمن مزامنة الرسائل الشخصية والوسائط والمكالمات كان الهاتف الذكي الأساسي تم تعريفه أنه الهاتف كان يحمل حساب واتساب الخاص نشط لفترة طويلة فسيتم تسجيل خروجك تلقائيا الهواتف المصاحبةوأكد موظفو واتساب أنه بغض النظر الجهاز يقوم بتشغيل حساب واتساب ستظل الدردشات مشفرة بالكامل يقرؤها طرفاها
# -------------------------
# Total occurrences of 'الحاسوب': 373
